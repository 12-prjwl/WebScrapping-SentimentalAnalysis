# %%
import pandas as pd
import csv
import urllib.parse
import os
import sys
from bs4 import BeautifulSoup
from itertools import islice
import requests
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer
from tqdm.notebook import tqdm
nltk.download('vader_lexicon')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\prajw\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\prajw\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
sheet = pd.read_csv('Input.csv')
# url = "https://insights.blackcoffer.com/what-jobs-will-robots-take-from-humans-in-the-future/"
# page = requests.get(url)

# %%
sheet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 963 entries, 0 to 962
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   URL_ID  114 non-null    float64
#  1   URL     114 non-null    object
# dtypes: float64(1), object(1)
# memory usage: 15.2+ KB

# %%
sheet.head()
# Out:
#    URL_ID                                                URL
# 0    37.0  https://insights.blackcoffer.com/ai-in-healthc...
# 1    38.0  https://insights.blackcoffer.com/what-if-the-c...
# 2    39.0  https://insights.blackcoffer.com/what-jobs-wil...
# 3    40.0  https://insights.blackcoffer.com/will-machine-...
# 4    41.0  https://insights.blackcoffer.com/will-ai-repla...

# %%
print(sheet['URL'])
# Out:
# 0      https://insights.blackcoffer.com/ai-in-healthc...
# 1      https://insights.blackcoffer.com/what-if-the-c...
# 2      https://insights.blackcoffer.com/what-jobs-wil...
# 3      https://insights.blackcoffer.com/will-machine-...
# 4      https://insights.blackcoffer.com/will-ai-repla...
#                              ...
# 958                                                  NaN
# 959                                                  NaN
# 960                                                  NaN
# 961                                                  NaN
# 962                                                  NaN
# Name: URL, Length: 963, dtype: object

# %%
sheet.shape
# Out:
# (963, 2)

# %%
file_path = 'Input.csv'  # Path to the CSV file
rows_to_read = 115  # Number of rows to read

with open(file_path, 'r', newline='') as csvfile:
    reader = csv.reader(csvfile)
    rows = islice(reader, rows_to_read)  # Limit the number of rows to read

    for row in rows:
        print(row)  # Process each row within the specified range
# Out:
# ['URL_ID', 'URL']
# ['37', 'https://insights.blackcoffer.com/ai-in-healthcare-to-improve-patient-outcomes/']
# ['38', 'https://insights.blackcoffer.com/what-if-the-creation-is-taking-over-the-creator/']
# ['39', 'https://insights.blackcoffer.com/what-jobs-will-robots-take-from-humans-in-the-future/']
# ['40', 'https://insights.blackcoffer.com/will-machine-replace-the-human-in-the-future-of-work/']
# ['41', 'https://insights.blackcoffer.com/will-ai-replace-us-or-work-with-us/']
# ['42', 'https://insights.blackcoffer.com/man-and-machines-together-machines-are-more-diligent-than-humans-blackcoffe/']
# ['43', 'https://insights.blackcoffer.com/in-future-or-in-upcoming-years-humans-and-machines-are-going-to-work-together-in-every-field-of-work/']
# ['44', 'https://insights.blackcoffer.com/how-neural-networks-can-be-applied-in-various-areas-in-the-future/']
# ['45', 'https://insights.blackcoffer.com/how-machine-learning-will-affect-your-business/']
# ...

# %%
a = sheet['URL'][:114]
a
# Out:
# 0      https://insights.blackcoffer.com/ai-in-healthc...
# 1      https://insights.blackcoffer.com/what-if-the-c...
# 2      https://insights.blackcoffer.com/what-jobs-wil...
# 3      https://insights.blackcoffer.com/will-machine-...
# 4      https://insights.blackcoffer.com/will-ai-repla...
#                              ...
# 109    https://insights.blackcoffer.com/blockchain-fo...
# 110    https://insights.blackcoffer.com/the-future-of...
# 111    https://insights.blackcoffer.com/big-data-anal...
# 112    https://insights.blackcoffer.com/business-anal...
# 113    https://insights.blackcoffer.com/challenges-an...
# Name: URL, Length: 114, dtype: object

# %%
for i in a:
    print(i)
# Out:
# https://insights.blackcoffer.com/ai-in-healthcare-to-improve-patient-outcomes/
# https://insights.blackcoffer.com/what-if-the-creation-is-taking-over-the-creator/
# https://insights.blackcoffer.com/what-jobs-will-robots-take-from-humans-in-the-future/
# https://insights.blackcoffer.com/will-machine-replace-the-human-in-the-future-of-work/
# https://insights.blackcoffer.com/will-ai-replace-us-or-work-with-us/
# https://insights.blackcoffer.com/man-and-machines-together-machines-are-more-diligent-than-humans-blackcoffe/
# https://insights.blackcoffer.com/in-future-or-in-upcoming-years-humans-and-machines-are-going-to-work-together-in-every-field-of-work/
# https://insights.blackcoffer.com/how-neural-networks-can-be-applied-in-various-areas-in-the-future/
# https://insights.blackcoffer.com/how-machine-learning-will-affect-your-business/
# https://insights.blackcoffer.com/deep-learning-impact-on-areas-of-e-learning/
# ...

# %%
b = []
for i in a:
    b.append(i)

# %%
# Out:
# 'https://insights.blackcoffer.com/what-if-the-creation-is-taking-over-the-creator/'

# %%
f = []
for i in range(3):
# Out:
# 0
# f 0
# 1
# f 1
# 2
# f 2

# %%
directory = 'D:/Placements/Internship/edited'  # Specify the directory where you want to create the files

# Create the directory if it doesn't exist
if not os.path.exists(directory):
    os.makedirs(directory)

for name in b:
    file_path = os.path.join(directory, f"{name}.txt")
    open(file_path, 'w').close()  # Create an empty text file
    print(f"Created empty file: {file_path}")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Input In [57], in <cell line: 7>()
#       7 for name in b:
#       8     file_path = os.path.join(directory, f"{name}.txt")
# ----> 9     open(file_path, 'w').close()  # Create an empty text file
#      10     print(f"Created empty file: {file_path}")
#
# OSError: [Errno 22] Invalid argument: 'D:/Placements/Internship/edited\\https://insights.blackcoffer.com/ai-in-healthcare-to-improve-patient-outcomes/.txt'

# %%
f1 = open(list[0],'w' )
# Out:
# str

# %%
for i in range(len(b)):
    url = b[i]
    print(url)


    for i in b:
          # Assuming my_list is the name of your list
        file_name = urllib.parse.quote_plus(url)  # Sanitize the URL to create a valid file name
        file_path = f"{file_name}.txt"

        with open(file_path, 'w') as f[i]:
            # Perform operations on the opened file
            # For example, write content to the file
            f1.write("This is the content of the file.")

# # File will be automatically closed after the `with` block
# Out:
# https://insights.blackcoffer.com/ai-in-healthcare-to-improve-patient-outcomes/
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [78], in <cell line: 1>()
#       3 print(url)
#       6 for i in b:
#       7       # Assuming my_list is the name of your list
# ----> 8     file_name = urllib.parse.quote_plus(url[i])  # Sanitize the URL to create a valid file name
#       9     file_path = f"{file_name}.txt"
#      11     with open(file_path, 'w') as f[i]:
#      12         # Perform operations on the opened file
#      13         # For example, write content to the file
#
# TypeError: string indices must be integers

# %%
# Out:
# 'https://insights.blackcoffer.com/challenges-and-opportunities-of-big-data-in-healthcare/'

# %%
url = "https://insights.blackcoffer.com/what-jobs-will-robots-take-from-humans-in-the-future/"
page = requests.get(url)
soup = BeautifulSoup(page.text,'html.parser')
soup


title = soup.title
title.text.strip()

print(head_tag)

firstOne = soup.find_all(attrs = {'class': 'td-post-content tagdiv-type'})


for i in firstOne:
    print(i.text)
    print('\n')
    
    
head_tag = soup.head.title.text
# Out:
# Introduction
# ...

# %%
# we can use url as b[0]
url = b[0]
url

for i in range(115):



url = "https://insights.blackcoffer.com/what-jobs-will-robots-take-from-humans-in-the-future/"
page = requests.get(url)
soup = BeautifulSoup(page.text,'html.parser')
soup


title = soup.title
title.text.strip()

print(head_tag)

firstOne = soup.find_all(attrs = {'class': 'td-post-content tagdiv-type'})


for i in firstOne:
    print(i.text)
    print('\n')
    
    
head_tag = soup.head.title.text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [83], in <cell line: 5>()
#       3 url
#       5 for i in range(115):
# ----> 6     url.append(b[i])
#
# AttributeError: 'str' object has no attribute 'append'

# %%
url = b[3]
url

page = requests.get(url)
soup = BeautifulSoup(page.text,'html.parser')
soup


title = soup.title
title.text.strip()

print(head_tag)

firstOne = soup.find_all(attrs = {'class': 'td-post-content tagdiv-type'})
contentInText = '\n'.join([element.text for element in firstOne])

# for i in firstOne:
#     print(i.text)
#     print('\n')
    
    
head_tag = soup.head.title.text

# txt1 = open('tempervary.txt', 'a')
# txt1.write(head_tag)
# txt1.write(contentInText)
with open('temporary.txt', 'a') as f:
        f.write(head_tag)  # Append the desired text to the file
        f.write("\n")
        f.write(contentInText)
# Out:
# Will Machine Replace The Human in the Future of Work? | Blackcoffer Insights

# %%
with open(3, 'w') as f3:
# Perform operations on the opened file
    # For example, write content to the file
    f3.write("This is the content of the file.")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Input In [92], in <cell line: 1>()
# ----> 1 with open(3, 'w') as f3:
#       2 # Perform operations on the opened file
#       3     # For example, write content to the file
#       4     f3.write("This is the content of the file.")
#
# OSError: [WinError 6] The handle is invalid

# %%
for i in range(37, 151):  # Range from 37 to 151 (inclusive)
    filename = f"{i}.txt"  # Construct the filename using the current number
    with open(filename, 'w') as f:
        # Perform any necessary operations on the file
        # Here, the file is empty as it has just been created
        pass  # Use 'pass' if you don't need to write anything to the file initially

# %%
for i in range(37, 151):  # Range from 37 to 151 (inclusive)
    filename = f"{i}.txt"  # Construct the filename using the current number
    with open(filename, 'a') as f:
        f.write("Text to append\n")  # Append the desired text to the file

# %%
def extraction(fileNo):
    url = "https://insights.blackcoffer.com/what-jobs-will-robots-take-from-humans-in-the-future/"
    page = requests.get(url)
    soup = BeautifulSoup(page.text,'html.parser')
    soup


    title = soup.title
    title.text.strip()

    print(head_tag)

    firstOne = soup.find_all(attrs = {'class': 'td-post-content tagdiv-type'})


    for i in firstOne:
        print(i.text)
        print('\n')


    head_tag = soup.head.title.text

# %%
for i in range(116):
    
    url = b[i]
    print("url is", b[i])
    print("\n")
    print("\n")
    page = requests.get(url)
    soup = BeautifulSoup(page.text,'html.parser')
    print("souped html",soup )
    print("\n")
    print("\n")


    title = soup.title
    title.text.strip()

    print("head tag,",head_tag)

    content = soup.find_all(attrs = {'class': 'td-post-content tagdiv-type'})
    contentInText = '\n'.join([element.text for element in content])

    # for i in firstOne:
    #     print(i.text)
    #     print('\n')


    head_tag = soup.head.title.text

    # txt1 = open('tempervary.txt', 'a')
    # txt1.write(head_tag)
    # txt1.write(contentInText)
    
    #-----------------------------------------------
    #this is important, but just for a experiment, its being happening
#     with open('temporary.txt', 'a') as f:
#             f.write(head_tag)  # Append the desired text to the file
#             f.write("\n")
#             f.write(contentInText)
            
    #------------------------------
    for i in range(37, 151):
        filename = f"{i}.txt"  # Construct the filename using the current number
        with open(filename, 'a') as f:
            f.write(head_tag)  # Append the desired text to the file
            f.write("\n")
            f.write(contentInText)

# %%
for i in range(48,116):
    
    url = b[i]
    print("url is", b[i])
    print("\n")
    print("\n")
    page = requests.get(url)
    soup = BeautifulSoup(page.text,'html.parser')
    print("souped html")
    print("\n")
    print("\n")


    title = soup.title
    title.text.strip()

    print("head tag,",head_tag)

    content = soup.find_all(attrs = {'class': 'td-post-content tagdiv-type'})
    contentInText = '\n'.join([element.text for element in content])

    # for i in firstOne:
    #     print(i.text)
    #     print('\n')


    head_tag = soup.head.title.text

    # txt1 = open('tempervary.txt', 'a')
    # txt1.write(head_tag)
    # txt1.write(contentInText)
    
    #-----------------------------------------------
    #this is important, but just for a experiment, its being happening
#     with open('temporary.txt', 'a') as f:
#             f.write(head_tag)  # Append the desired text to the file
#             f.write("\n")
#             f.write(contentInText)
            
    #------------------------------
    filename = f"{i+37}.txt"  # Construct the filename using the current number
    with open(filename, 'a',encoding='utf-8') as f:
        f.write(head_tag)  # Append the desired text to the file
        f.write("\n")
        f.write(contentInText)
# Out:
# url is https://insights.blackcoffer.com/impacts-of-covid-19-on-vegetable-vendors-and-food-stalls/
#
#
#
#
# souped html
#
#
#
#
# head tag, How Small Business can survive the Coronavirus Crisis | Blackcoffer Insights
# url is https://insights.blackcoffer.com/impacts-of-covid-19-on-vegetable-vendors/
#
#
#
#
# souped html
#
#
#
#
# head tag, Impacts of COVID 19 on Food products | Blackcoffer Insights
# url is https://insights.blackcoffer.com/impact-of-covid-19-pandemic-on-tourism-aviation-industries/
#
#
#
#
# souped html
#
#
#
#
# head tag, Impacts of COVID 19 on Vegetable Vendors | Blackcoffer Insights
# url is https://insights.blackcoffer.com/impact-of-covid-19-pandemic-on-sports-events-around-the-world/
#
#
#
#
# souped html
#
#
#
#
# head tag, Impact of COVID-19 pandemic on Tourism & Aviation industries | Blackcoffer Insights
# url is https://insights.blackcoffer.com/changing-landscape-and-emerging-trends-in-the-indian-it-ites-industry/
#
#
#
#
# souped html
#
#
#
#
# ...

# %%
#using direct text method i.e. not fetching from excel
sia = SentimentIntensityAnalyzer()
sia

# %%
# The original code to print all three sentiments at once


articles = []
pos = []
neg = []
nue = []
compound = []
avgLen = []



for i in range(0,3):
   
    
    filename = f"{i+37}.txt"  # Construct the filename using the current number
    with open(filename, 'r',encoding='utf-8',errors='replace') as f:
        toAnalyze = f.read()
        score = sia.polarity_scores(toAnalyze)
#         print(toAnalyze)
        articles.append(toAnalyze)
        


        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
#         articles.append(toAnalyze + '\n')
        
        print("".join(articles))
        neg.append(score['neg'])
        pos.append(score['pos'])
        neu.append(score['neu'])
        compound.append(score['compound'])
        

        
        

    #         f.write(head_tag)  # Append the desired text to the file
    #         f.write("\n")
    #         f.write(contentInText)
# Out:
# What if the Creation is Taking Over the Creator? | Blackcoffer Insights
#
# Human minds, a fascination in itself carrying the potential of tinkering nature with the pixie dust intelligence, creating and solving the mysteries and wonders with anything but admiration. However, no matter how captivating a human mind can be, it could sometimes be appalled. It could be the hunger or maybe the desire to want more, to go beyond and unravel the limitations, or maybe something like pure greed. Humans have never stopped and always keep evolving when it comes to intelligence and this is what makes them the supreme.
# ...

# %%
print(compound)


# Initialize an empty list for subjectivity scores
subjectivity = []

# Calculate the subjectivity score for each compound score
for score in compound:
    subjectivity_score = abs(score)
    subjectivity.append(subjectivity_score)

print("Subjectivity Scores:", subjectivity)







# compound_score = score["compound"]

#     # Calculate the sentiment intensity
# sub = abs(compound_score)

#     # Estimate the subjective score based on sentiment intensity
# subjective_score = sentiment_intensity

# print("Subjective Score:", sub)
# Out:
# [0.0, 0.9984, 0.9891]
# Subjectivity Scores: [0.0, 0.9984, 0.9891]

# %%
with open('38.txt', 'r',encoding='utf-8',errors='replace') as f:
    anal = f.read()
    print(sia.polarity_scores(anal))
# Out:
# {'neg': 0.083, 'neu': 0.768, 'pos': 0.149, 'compound': 0.9984}

# %%
print("negative value: ",content_Scores['neg'])
# content_Scores['neu']
# content_Scores['pos']

# %%
df = pd.read_csv('dummyOutput.csv')

# %%
df.head()
# Out:
#    URL_ID                                                URL  POSITIVE SCORE  \
# 0    37.0  https://insights.blackcoffer.com/ai-in-healthc...             NaN
# 1    38.0  https://insights.blackcoffer.com/what-if-the-c...             NaN
# 2    39.0  https://insights.blackcoffer.com/what-jobs-wil...             NaN
# 3    40.0  https://insights.blackcoffer.com/will-machine-...             NaN
# 4    41.0  https://insights.blackcoffer.com/will-ai-repla...             NaN
#
#    NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  AVG SENTENCE LENGTH  \
# 0             NaN             NaN                 NaN                  NaN
# 1             NaN             NaN                 NaN                  NaN
# 2             NaN             NaN                 NaN                  NaN
# 3             NaN             NaN                 NaN                  NaN
# 4             NaN             NaN                 NaN                  NaN
#
# ...

# %%
#1 inserting Positive score, and Negative score

df.loc[:2, "POSITIVE SCORE"] = pos
df.loc[:2, "SUBJECTIVITY SCORE"] = subjectivity

# %%
# average length of sentences: 

text = """Human minds, a fascination in itself carrying the potential of tinkering nature with the pixie dust intelligence, creating and solving the mysteries and wonders with anything but admiration. However, no matter how captivating a human mind can be, it could sometimes be appalled. It could be the hunger or maybe the desire to want more, to go beyond and unravel the limitations, or maybe something like pure greed. Humans have never stopped and always keep evolving when it comes to intelligence and this is what makes them the supreme.
Intelligence calls out for supremacy and so, what if there was to evolve something that opposed a challenge to the very human minds, to their capabilities while making them question their own importance among themselves? Artificial Intelligence came as a revolution, havoc when it first came to the light. The concept of making machines does work on their own, like granting machines �The Intelligence.
The idea of making machines work like humans came back in the 19s. Back then people didn�t believe in such a thing as making a non-living thing work, think, and carry tasks on its own, not to mention, to actually surpass humans themselves in those skills. The facts are it did. By 1997. The greatest chess player, Garry Kasparov was defeated in a chess game by a machine and this is where exactly, a top skilled human lost to a mere machine created by another who by himself could�ve never defeated him. It was a rule of power, of betterment, of skills, and the granted supremacy. Were AI and Machines just tools? Equipment?� Something that helped an unskilled person with his mind and intelligence creates something that could do the skilled work for him with perfection and precision? Well initially it was, however, as time passed as humans got drawn to the puzzle of AI, a lot changed. Human research went deeper and deeper and as a result, the machines evolved with it. """
    # Tokenize the text into sentences
sentences = nltk.sent_tokenize(text)

    # Calculate the length of each sentence
sentence_lengths = [len(nltk.word_tokenize(sentence)) for sentence in sentences]

    # Compute the average sentence length
average_length = sum(sentence_lengths) / len(sentence_lengths)

print(average_length)
# Out:
# 21.647058823529413

# %%
df.head()
# Out:
#    URL_ID                                                URL  POSITIVE SCORE  \
# 0    37.0  https://insights.blackcoffer.com/ai-in-healthc...           0.000
# 1    38.0  https://insights.blackcoffer.com/what-if-the-c...           0.149
# 2    39.0  https://insights.blackcoffer.com/what-jobs-wil...           0.075
# 3    40.0  https://insights.blackcoffer.com/will-machine-...             NaN
# 4    41.0  https://insights.blackcoffer.com/will-ai-repla...             NaN
#
#    NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  AVG SENTENCE LENGTH  \
# 0             NaN             NaN              0.0000                  NaN
# 1             NaN             NaN              0.9984                  NaN
# 2             NaN             NaN              0.9891                  NaN
# 3             NaN             NaN                 NaN                  NaN
# 4             NaN             NaN                 NaN                  NaN
#
# ...

# %%
#2 Inserting Subjectivity score
# subjective score is the absoulte of the compound score

# %%
#3 Inserting average sentence length

# %%
#4 Inserting percentage of complex words

# %%
#5 Inserting FOG index

# %%
#6 Inserting Average no. of Words per sentence
